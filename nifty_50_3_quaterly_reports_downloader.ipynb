# %%
import os
import requests
import pandas as pd

from bs4 import BeautifulSoup

import undetected_chromedriver as uc
from selenium.webdriver.common.keys import Keys

from time import sleep
# %config Completer.use_jedi = False

import warnings
warnings.filterwarnings("ignore")

from pprint import pprint
from selenium import webdriver
# import pyautogui

# !pip install undetected_chromedriver

# !conda install -c conda-forge pyautogui -y

# %%
download_loc = "./quaterly_reports/nifty_50/"

if not os.path.exists(download_loc):
    os.makedirs(download_loc)

# %%
company_details_df = pd.read_csv("./company_details.csv")
company_details_df
# Out:
#                                     Company Name                  Industry  \
# 0     Adani Ports and Special Economic Zone Ltd.                  SERVICES
# 1                              Asian Paints Ltd.            CONSUMER GOODS
# 2                                 Axis Bank Ltd.        FINANCIAL SERVICES
# 3                                Bajaj Auto Ltd.                AUTOMOBILE
# 4                             Bajaj Finance Ltd.        FINANCIAL SERVICES
# 5                             Bajaj Finserv Ltd.        FINANCIAL SERVICES
# 6              Bharat Petroleum Corporation Ltd.                 OIL & GAS
# 7                             Bharti Airtel Ltd.                   TELECOM
# 8                      Britannia Industries Ltd.            CONSUMER GOODS
# 9                                     Cipla Ltd.                    PHARMA
# 10                               Coal India Ltd.                    METALS
# ...

# %%
print('Downloading started . . .')

# # starting chrome driver
# driver = uc.Chrome()

# %%
# page_source = BeautifulSoup(driver.page_source)
# quaterly_reports_info = page_source.findAll('tbody')[0].findAll('tr')
# len(quaterly_reports_info)

# required_reports_info = {}
# processed_quarters = {}
# for position,reports in enumerate(quaterly_reports_info):
#     year_info = reports.find_all('td')[len(reports.find_all('td'))-3].text
#     if str(reports).find('Non-Consolidated') != -1 and year_info not in processed_quarters:
#         processed_quarters[year_info] = 0
#         if str(reports).find('xbrl') != -1:
#             required_reports_info[position+1] = [reports, reports.find_all('a', href=True)[1]['href']]
#         else:
#             required_reports_info[position+1] = [reports, 0]
# len(required_reports_info)

# %%
# for position,info in required_reports_info.items():
#     quarter_info = info[0].find_all('td')[len(info[0].find_all('td'))-2].text
#     year_info = info[0].find_all('td')[len(info[0].find_all('td'))-3].text
#     print(year_info, quarter_info)
    
#     save_loc = os.path.join(download_loc, year.split('-')[-1], '_'.join(quarter_info.split(' ')))
#     if not os.path.exists(save_loc)
#         os.makedirs(save_loc)
    
#     file_name = quarter_info.split(' ')
#     for temp in year_info.split('-'):
#         file_name.append(temp)
#     file_name = '_'.join(file_name)
#     print(file_name)
    
    
    
#     if info[1] != 0:
#         # open new driver
#         driver_1 = uc.Chrome()
#         driver_1.get(info[1])
#         xblr_content = BeautifulSoup(driver.page_source).body.div
#         xblr_content = str(xblr_content)[len('<div id="webkit-xml-viewer-source-xml">'):]
#         xblr_content = xblr_content[:len(xblr_content)-len('</div>')]

#         xblr_file_path = os.path.join(save_loc, file_name + '.xml')
#         with open(xblr_file_path,'w') as fp:
#             fp.writelines(xblr_content)
    
     
#     scrolling_element= driver.find_element_by_xpath('//*[@id="CFfinancialequityTable"]/tbody/tr[{}]/td[1]'.format(position-10))    
#     driver.execute_script('arguments[0].scrollIntoView(true);', scrolling_element)
    
#     search_button = driver.find_element_by_xpath('//*[@id="CFfinancialequityTable"]/tbody/tr[{}]/td[1]/a'.format(position))
#     search_button.click()
    
#     try:
#         driver.switch_to.window(driver.window_handles[1])
#     except:
#         pass
    
#     html_file_path = os.path.join(save_loc, file_name + '.html')
#     with open(html_file_path) as fp:
#         fp.writelines(driver.page_source)
    
#     driver.switch_to.window(driver.window_handles[0])

# %%
# for i,values in enumerate(company_details_df.values):
#     company_name = values[0]
#     company_symbol = values[2]
#     print("\n{0:5}. {1:16} :: {2:5}".format(i+1, company_symbol, company_name), end=' :: ')
    
#     # visiting the webpage
#     driver.get('https://www.nseindia.com/companies-listing/corporate-filings-financial-results')
#     sleep(5)
    
#     # inserting company symbol in search field
#     search_field = driver.find_element_by_id('financials_equities_companyName')
#     search_field.send_keys(company_symbol)
#     sleep(5)
#     search_field.send_keys(Keys.DOWN, Keys.ENTER)
#     sleep(5)
    
#     page_source = BeautifulSoup(driver.page_source)
#     quaterly_reports_info = page_source.findAll('tbody')[0].findAll('tr')
# #     len(quaterly_reports_info)

#     required_reports_info = {}
#     processed_quarters = {}
#     for position,reports in enumerate(quaterly_reports_info):
#         year_info = reports.find_all('td')[len(reports.find_all('td'))-3].text
#         if str(reports).find('Non-Consolidated') != -1 and year_info not in processed_quarters:
#             processed_quarters[year_info] = 0
#             if str(reports).find('xbrl') != -1:
#                 required_reports_info[position+1] = [reports, reports.find_all('a', href=True)[1]['href']]
#             else:
#                 required_reports_info[position+1] = [reports, 0]
#     print(len(required_reports_info), end=' ')
    
#     xbrl_files_track = {}
#     for position,info in required_reports_info.items():
#         quarter_info = info[0].find_all('td')[len(info[0].find_all('td'))-2].text
#         year_info = info[0].find_all('td')[len(info[0].find_all('td'))-3].text
# #         print(year_info, quarter_info)

#         save_loc = os.path.join(download_loc,company_symbol ,year_info.split('-')[-1], '_'.join(quarter_info.split(' ')))
#         if not os.path.exists(save_loc):
#             os.makedirs(save_loc)

#         file_name = quarter_info.split(' ')
#         for temp in year_info.split('-'):
#             file_name.append(temp)
#         file_name = '_'.join(file_name)
# #         print(file_name)



#         if info[1] != 0:
#             xbrl_files_track[os.path.join(save_loc, file_name + '.xml')] = info[1] 
#             # open new driver
            
# #             driver.execute_script('''window.open("{}","_blank");'''.format(info[1]))
# #             sleep(5)
# #             driver.switch_to.window(driver.window_handles[1])
            
# #             driver_1 = uc.Chrome()
# #             driver_1.get(info[1])

# #             driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + 't')
# #             driver.get(info[1])

# #             xblr_content = BeautifulSoup(driver.page_source).body.div
# #             xblr_content = str(xblr_content)[len('<div id="webkit-xml-viewer-source-xml">'):]
# #             xblr_content = xblr_content[:len(xblr_content)-len('</div>')]

# #             xblr_file_path = os.path.join(save_loc, file_name + '.xml')
# #             with open(xblr_file_path,'w') as fp:
# #                 fp.writelines(xblr_content)

# #             driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + 'w')
            
        
#         new_pos = 1 if position < 15 else position-10
#         if new_pos != 1:
#             scrolling_element= driver.find_element_by_xpath('//*[@id="CFfinancialequityTable"]/tbody/tr[{}]/td[1]'.format(new_pos))    
#             driver.execute_script('arguments[0].scrollIntoView(true);', scrolling_element)

#         search_button = driver.find_element_by_xpath('//*[@id="CFfinancialequityTable"]/tbody/tr[{}]/td[1]/a'.format(position))
#         search_button.click()

#         try:
#             driver.switch_to.window(driver.window_handles[1])
#             html_file_path = os.path.join(save_loc, file_name + '.html')
#             with open(html_file_path, 'w') as fp:
#                 fp.writelines(driver.page_source)
#             driver.close()
#             driver.switch_to.window(driver.window_handles[0])
            
#         except:

#             html_file_path = os.path.join(save_loc, file_name + '.html')
#             with open(html_file_path,'w') as fp:
#                 fp.writelines(driver.page_source)
                
#             driver.switch_to.window(driver.window_handles[0])
            
#             # visiting the webpage
#             driver.get('https://www.nseindia.com/companies-listing/corporate-filings-financial-results')
#             sleep(5)

#             # inserting company symbol in search field
#             search_field = driver.find_element_by_id('financials_equities_companyName')
#             search_field.send_keys(company_symbol)
#             sleep(5)
#             search_field.send_keys(Keys.DOWN, Keys.ENTER)
#             sleep(5)
            
#             page_source = BeautifulSoup(driver.page_source)
#             quaterly_reports_info = page_source.findAll('tbody')[0].findAll('tr')
#         #     len(quaterly_reports_info)

#             required_reports_info = {}
#             processed_quarters = {}
#             for position,reports in enumerate(quaterly_reports_info):
#                 year_info = reports.find_all('td')[len(reports.find_all('td'))-3].text
#                 if str(reports).find('Non-Consolidated') != -1 and year_info not in processed_quarters:
#                     processed_quarters[year_info] = 0
#                     if str(reports).find('xbrl') != -1:
#                         required_reports_info[position+1] = [reports, reports.find_all('a', href=True)[1]['href']]
#                     else:
#                         required_reports_info[position+1] = [reports, 0]
# #             print(len(required_reports_info), end=' ')
            
            
            
#     for xbrl_file_path,xbrl_url in xbrl_files_track.items():
        
#             driver.get(xbrl_url)
#             xblr_content = BeautifulSoup(driver.page_source).body.div
#             xblr_content = str(xblr_content)[len('<div id="webkit-xml-viewer-source-xml">'):]
#             xblr_content = xblr_content[:len(xblr_content)-len('</div>')]

#             with open(xblr_file_path,'w') as fp:
#                 fp.writelines(xblr_content)
    
# print('Downloading Completed')

# %%
for i,values in enumerate(company_details_df.values):
    company_name = values[0]
    company_symbol = values[2]
    print("\n{0:5}. {1:16} :: {2:5}".format(i+1, company_symbol, company_name), end=' :: ')

    if i>37:
        # starting chrome driver

        driver = uc.Chrome()
        sleep(10)

        # visiting the webpage
        driver.get('https://www.nseindia.com/companies-listing/corporate-filings-financial-results')
        sleep(15)

        # inserting company symbol in search field
        search_field = driver.find_element_by_id('financials_equities_companyName')
        search_field.send_keys(company_symbol)
        sleep(7)
        search_field.send_keys(Keys.DOWN, Keys.ENTER)
        sleep(7)


        page_source = BeautifulSoup(driver.page_source)
        quaterly_reports_info = page_source.findAll('tbody')[0].findAll('tr')

        #     len(quaterly_reports_info)

        required_reports_info = {}
        processed_quarters = {}
        for position,reports in enumerate(quaterly_reports_info):
            year_info = reports.find_all('td')[len(reports.find_all('td'))-3].text
            if str(reports).find('Non-Consolidated') != -1 and year_info not in processed_quarters:
                processed_quarters[year_info] = 0
                if str(reports).find('xbrl') != -1:
                    required_reports_info[position+1] = [reports, reports.find_all('a', href=True)[1]['href']]
                else:
                    required_reports_info[position+1] = [reports, 0]
        print(len(required_reports_info), end=' ')


    #     sleep(10)
    #     xbrl_files_track = {}
    #     for position,info in required_reports_info.items():
    #         quarter_info = info[0].find_all('td')[len(info[0].find_all('td'))-2].text
    #         year_info = info[0].find_all('td')[len(info[0].find_all('td'))-3].text

    #         if year_info.split('-')[1] == 'Mar':
    #             save_loc = os.path.join(download_loc,company_symbol ,str(int(year_info.split('-')[-1])-1), '_'.join(quarter_info.split(' ')))
    #         else:
    #             save_loc = os.path.join(download_loc,company_symbol ,year_info.split('-')[-1], '_'.join(quarter_info.split(' ')))

    #         if not os.path.exists(save_loc):
    #             os.makedirs(save_loc)

    #         file_name = quarter_info.split(' ')
    #         for temp in year_info.split('-'):
    #             file_name.append(temp)
    #         file_name = '_'.join(file_name)
    # #         print('\t', file_name, end = ' ')
    #         driver.execute_script("window.scrollTo(0, 400)") 
    #         if info[1] != 0:
    #             xbrl_files_track[os.path.join(save_loc, file_name + '.xml')] = info[1] 

    #         new_pos = 1 if position < 10 else position-5
    #         if new_pos != 1:
    #             scrolling_element= driver.find_element_by_xpath('//*[@id="CFfinancialequityTable"]/tbody/tr[{}]/td[1]'.format(new_pos))    
    #             driver.execute_script('arguments[0].scrollIntoView(true);', scrolling_element)

    #         search_button = driver.find_element_by_xpath('//*[@id="CFfinancialequityTable"]/tbody/tr[{}]/td[1]/a'.format(position))
    #         search_button.click()
    #         sleep(10)

    #         try:
    #             driver.switch_to.window(driver.window_handles[1])
    #             html_file_path = os.path.join(save_loc, file_name + '.html')
    #             with open(html_file_path, 'w', encoding="utf-8") as fp:
    #                 fp.writelines(driver.page_source)
    #             driver.close()
    #             driver.switch_to.window(driver.window_handles[0])

    #         except:

    #             html_file_path = os.path.join(save_loc, file_name + '.html')
    #             details_page_source = BeautifulSoup(driver.page_source)
    #             with open(html_file_path,'w',encoding="utf-8") as fp:
    #                 fp.writelines(str(details_page_source.findAll(class_='modal qlinks_modal fullView')[0]))

    #             webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()


    #     sleep(10)
    #     for xbrl_file_path,xbrl_url in xbrl_files_track.items():

    #             driver.get(xbrl_url)
    #             sleep(10)
    #             xbrl_content = BeautifulSoup(driver.page_source).body.div
    #             xbrl_content = str(xbrl_content)[len('<div id="webkit-xml-viewer-source-xml">'):]
    #             xbrl_content = xbrl_content[:len(xbrl_content)-len('</div>')]

    #             with open(xbrl_file_path,'w' ,encoding="utf-8") as fp:
    #                 fp.writelines(xbrl_content)
        driver.quit()
        sleep(10)
# Out:
#     1. ADANIPORTS       :: Adani Ports and Special Economic Zone Ltd. ::
#     2. ASIANPAINT       :: Asian Paints Ltd. ::
#     3. AXISBANK         :: Axis Bank Ltd. ::
#     4. BAJAJ-AUTO       :: Bajaj Auto Ltd. ::
#     5. BAJFINANCE       :: Bajaj Finance Ltd. ::
#     6. BAJAJFINSV       :: Bajaj Finserv Ltd. ::
#     7. BPCL             :: Bharat Petroleum Corporation Ltd. ::
#     8. BHARTIARTL       :: Bharti Airtel Ltd. ::
#     9. BRITANNIA        :: Britannia Industries Ltd. ::
#    10. CIPLA            :: Cipla Ltd. ::
#    11. COALINDIA        :: Coal India Ltd. ::
#    12. DIVISLAB         :: Divi's Laboratories Ltd. ::
#    13. DRREDDY          :: Dr. Reddy's Laboratories Ltd. ::
#    14. EICHERMOT        :: Eicher Motors Ltd. ::
#    15. GRASIM           :: Grasim Industries Ltd. ::
#    16. HCLTECH          :: HCL Technologies Ltd. ::
#    17. HDFCBANK         :: HDFC Bank Ltd. ::
#    18. HDFCLIFE         :: HDFC Life Insurance Company Ltd. ::
# ...

# %%
company_symbol
# Out:
# 'SBILIFE'

# %%
position

# %%
scrolling_element= driver.find_element_by_xpath('//*[@id="CFfinancialequityTable"]/tbody/tr[{}]'.format(6))    
driver.execute_script('arguments[0].scrollIntoView(true);', scrolling_element)
